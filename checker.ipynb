# %%
from bs4 import BeautifulSoup
import urllib
import requests
import json
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO
import re
import string

# %%
def check(original):
    text = original
    text = urllib.parse.quote(text)
    text = '"' + text + '"'
    url = 'https://google.com/search?q={}'.format(text)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    for g in soup.find_all(class_='ZINbbc xpd O9g5cc uUPGi'):
        here = (original in g.text and "did not match any documents" not in g.text)
        if here:
            s = original + "\n" + "----------------------------" + "\n" + g.text
            return(s)
    return ''

# %%
def convert_pdf_to_txt(pdf_filepath, password='', max_pages=0, caching=True, page_num=set()):
     
    rsrcmgr = PDFResourceManager()
    laparams = LAParams()

    # Change codec if needed.
    codec = 'utf-8'  # 'utf16','utf-8'
    with StringIO() as return_string, open(pdf_filepath, 'rb') as open_file:
        with TextConverter(rsrcmgr, return_string, codec=codec, laparams=laparams) as device:
            interpreter = PDFPageInterpreter(rsrcmgr, device)
            for page in PDFPage.get_pages(open_file, page_num, maxpages=max_pages, password=password, caching=caching, check_extractable=True):
                interpreter.process_page(page)
            paper_string = return_string.getvalue()
            # print(paper_string)
            return paper_string

# %%
def find_quotes(text):
    inquote = False
    quotes = []
    index = 0
    for item in text.split():
        curr = len(quotes)-1
        if(len(item.strip()) > 0 and item):
            try:
                if(inquote):
                        quotes[curr] = quotes[curr] + " " + item
                elif(item[0] == "\"" or item[0] == '“'): 
                    inquote = True
                    quotes.append(item)
                if(item[len(item)-1] == "\"" or item[len(item)-1] == '”' or item[len(item)-2] == "\"" or item[len(item)-2] == '”'):
                            inquote = False
            except Exception as e: 
                print(e)
                print(item)
                print(index)
                print(quotes)
                print(len(quotes))
                break
    for index in range(len(quotes)):
        curr = quotes[index]
        quotes[index] = curr[1:len(curr)-1]
        quotes[index] = quotes[index].replace(u'’', u"'")
        quotes[index] = quotes[index].replace(u'”', u"")
        quotes[index] = quotes[index].replace('- ', '')
        
    returnlist = [x for x in quotes if (len(x.split()) > 1)]

    return(returnlist)

# %%
def check_quotes(quotes):
    for quote in quotes:
        test = check(quote)
        if test:
            print(test)
            print()

# %%
import os

directory = r'./PDFs'
for filename in os.listdir(directory):
    if filename.endswith(".pdf"):
        print(filename)
        print()
        check_quotes(find_quotes(convert_pdf_to_txt('./PDFs/' + filename)))
        print()
# Out:
# Abokhodair et al. - 2017 - Photo Sharing in the Arab Gulf Expressing the Col.pdf
#
# online repositories of digital selfpresentation
# ----------------------------
# Showing results for "online repositories of digital self presentation"Search instead for "online repositories of digital selfpresentation"
#
# digital image.
# ----------------------------
# 1. What is a digital Image? - Learn ImageJ - Google Siteshttps://sites.google.com › site › learnimagej › image-processing › what-is-a...I'll skip explaining what a picture is and begin defining a digital image. Digital images are made of picture elements called pixels. Typically, pixels are organized ...
#
# front stage
# ----------------------------
# Erving Goffman's Front Stage and Back Stage Behavior - ThoughtCohttps://www.thoughtco.com › Social Sciences › SociologyJul 14, 2019 · In sociology, the terms "front stage" and "back stage" refer to different behaviors that people engage in every day. Developed by the late ...
#
# back stage
# ----------------------------
# People also askWhat are the back stage and front stage areas of your life?Is Backstage legit?What is the concept of dramaturgy?What is backstage casting?
#
# to constitute agentic discursive identities
# ----------------------------
# 'Snapchat', youth subjectivities and sexuality: disappearing media ...https://www.tandfonline.com › doi › fullThe technological affordance of disappearing media supports opportunities for students to constitute agentic discursive identities yet it also magnifies and ...
#
# bring a lot of harm to women, even if the picture shows only a partial view of her [28].
# ----------------------------
# Photo Sharing in the Arab Gulf: Expressing the Collective and ...docplayer.net › 148659019-Photo-sharing-in-the-arab-gulf-expressing-the-...And the sharing of these photos can bring a lot of harm to women, even if the picture shows only a partial view of her [28]. Given these rules and norms in the ...
#
# sexual in nature
# ----------------------------
# Does Sexual Harassment Have To Be Sexual In Nature?https://www.sexualharassmenttraining.com › blog › detail › does-sexual-ha...Jan 28, 2019 · Such a thing is not sexual in nature, but like all other forms of sexual harassment, it can explicitly or implicitly affect a worker's employment, ...
#
# family compound
# ----------------------------
# People also askWhat is family compound?What is living on a compound?How many houses can you build on 5 acres?Can you build on your parents property?
#
# traditional culture
# ----------------------------
# Traditional Culture and Modern Culture: Man's Fall from Grace ...https://www.huffpost.com › entry › traditional-culture-and-m_b_655992Jul 26, 2010 · In some ways, traditional culture and modern culture are alike. Any culture is a system of learned and shared meanings. People learn and ...
#
# a culture
# ----------------------------
# People also askWhat is an example of a culture?What do you mean by culture?What are the 4 types of culture?What are 5 examples of culture?
#
# Thinking with
# ----------------------------
# See results aboutThinking with Type (Book by Ellen Lupton)Originally published: September 9, 2004
# Author: Ellen Lupton
#
# situated character of knowledge
# ----------------------------
# Qualitative Research and Critical Social Psychology in Chile Today ...www.qualitative-research.net › Home › Vol 7, No 4 (2006)Sep 11, 2006 · This speaks to us of the situated character of knowledge. As a process that is effected from a place—that of the investigator—interpretation "is ...
#
# layers of meaning
# ----------------------------
# 1. Definition (expr.) complexity; intellectual depth. Examples That book has several layers of meaning.What does "several layers of meaning" mean? | Learn English at ...https://www.englishbaby.com › vocab › word › several-layers-of-meaning
#
# thinking with
# ----------------------------
# Thinking With Typethinkingwithtype.comPraise for Ellen Lupton's book. Thinking with Type “Type is the foundation of print and web design. Everything you need to know about thinking with type, you will ...
# Letter · Grid · Text · Extras
#
# thinking with
# ----------------------------
# Thinking With Typethinkingwithtype.comPraise for Ellen Lupton's book. Thinking with Type “Type is the foundation of print and web design. Everything you need to know about thinking with type, you will ...
# Letter · Grid · Text · Extras
#
# the presentation of the self in everyday life
# ----------------------------
# Scholarly articles for "the presentation of the self in everyday life"scholar.google.com › citationsThe presentation of the charismatic self in everyday life: …Joosse • Cited by 23Goffman and social organization: Studies of a …Smith • Cited by 92'The whole nation is listening to you': the presentation …O&#39;Sullivan • Cited by 45
#
# the researcher records information from the viewpoint of the people engaged in the social behavior under investigation
# ----------------------------
# Photo Sharing in the Arab Gulf: Expressing the Collective and ...docplayer.net › 148659019-Photo-sharing-in-the-arab-gulf-expressing-the-...Developing codes emically means that the researcher records information from the viewpoint of the people engaged in the social behavior under investigation ...
#
# …a thorough specification of the characteristics of the sample
# ----------------------------
# [PDF] 1 © Copyright 2017 Norah Abdulwahab ... - Semantic Scholarhttps://pdfs.semanticscholar.org › ...apply my findings based on “…a thorough specification of the characteristics of the sample”. (Elliott & Timulak, 2005). In other words, people who share the ...
#
# The Wild Cards
# ----------------------------
# Wild Cards (Wild Cards, #1) by George R.R. Martin - Goodreadshttps://www.goodreads.com › book › show › 147908.Wild_CardsRating  3.7  (11,161) In my opinion, The Wild Cards novels are the best ongoing series of short stories available today. When I heard that Tor Books was re-releasing the first novel I ...
#
# standard bearer
# ----------------------------
# People also askWhat does it mean to be a standard bearer?What is a standard bearer in golf?How did standard bearers fight?How is the youth standard bearer of a nation?
#
# be more authentic
# ----------------------------
# Develop Authenticity: 20 Ways to Be a More Authentic Person ...https://www.psychologytoday.com › blog › click-here-happiness › develop...Apr 15, 2019 · Do you have a hard time being your true self? Then try these 20 "authenticity strategies" to be more authentic in your daily life.
#
# whatever represents me more,
# ----------------------------
# Photo Sharing in the Arab Gulf: Expressing the Collective and ...docplayer.net › 148659019-Photo-sharing-in-the-arab-gulf-expressing-the-...When she mentions she would like to be more authentic and do whatever represents me more, she is referring to her wish to put forth an autonomous self that ...
#
# Westernized appearance
# ----------------------------
# [PDF] Body Image and Westernization Trends Among Japanese ... - ERIChttps://files.eric.ed.gov › fulltexttanner, more Westernized appearance as evidence of one's leisure time in the sun (Hall-Iijima, 1995). Hair color has also become increasingly Westernized, ...
#
# they will think you are a bad girl,
# ----------------------------
# Photo Sharing in the Arab Gulf - ACM Digital Libraryhttps://dl.acm.org › doi › pdfMar 1, 2017 · When she says “they will think you are a bad girl,” the “they” refers to society as a whole. She is referring to the fact that she will be judged not ...
#
# double standard
# ----------------------------
#  dou·ble stand·ard/ˈdəbəl ˈstandərd/noun
# a rule or principle which is unfairly applied in different ways to different people or groups."the prolonged consideration of the issue represented a double standard"
#
# double identity
# ----------------------------
# Related searchesdouble identity quotes>double identity audiobook>double identity review>double identity book cover>double identity definition>double identity setting>double identity movie>double identity book trailer>
#
# maintain social boundaries and show different facets
# ----------------------------
# Faceted identity, faceted lives - ACM Digital Libraryhttps://dl.acm.org › doi › pdfmaintain social boundaries and show different facets or sides of their character according to the demands of the current social situation. A deeper understanding  ...
#
# a researcher is not readily accepted in a traditional milieu that frowns upon those enquiring into other peoples' lives
# ----------------------------
# Women in Saudi Arabia Todayhttps://books.google.com › booksHowever I was mistaken because a researcher is not readily accepted in a traditional milieu that frowns upon those enquiring into other peoples' lives. A true  ...
#
# think with
# ----------------------------
# Related searchesthink with google>think with google stats>consumer barometer>think with google uk>think with google tools>google marketing news>google trends newsletter>google research tools>
#
# The Presentation of Self In The Age Of Social Media: Distinguishing Performances And Exhibitions Online.
# ----------------------------
# Scholarly articles for "The Presentation of Self In The Age Of Social Media: Distinguishing Performances And Exhibitions Online."scholar.google.com › citations… age of social media: Distinguishing performances and …Hogan • Cited by 1088
#
# Domains of privacy and hospitality in Arab Gulf homes.
# ----------------------------
# (PDF) Domains of privacy and hospitality in Arab Gulf homeshttps://www.researchgate.net › publication › 241699027_Domains_of_priv...Dec 29, 2014 · Domains of privacy and hospitality in Arab Gulf homes. Article (PDF Available) in Journal of Islamic Marketing 2(2):125-137 · June 2011 with ...
#
#
# Ahmed and Fuge - 2017 - Capturing Winning Ideas in Online Design Communiti.pdf
#
#
# Almuhimedi et al. - 2013 - Tweets are forever a large-scale quantitative ana.pdf
#
# location deletion notice
# ----------------------------
# Replace streaming.py - GitLab Community Editionhttps://lab.textdata.org › lambda › lib › python3.6 › site-packages › tweepy... def on_scrub_geo(self, notice): """Called when a location deletion notice arrives""" return def on_status_withheld(self, notice): """Called when a status withheld ...
#
# user ID
# ----------------------------
# Creating a User ID and Password in EBSCOadmin - Tutorial ...https://www.youtube.com › watchJun 4, 2015 · In this Administrator Quick Tips Tutorial, learn how to use EBSCOadmin to create user ID and ...Duration: 1:24
# Posted: Jun 4, 2015
#
# up-to-status ID
# ----------------------------
# [PDF] Tweets Are Forever: A Large-Scale Quantitative Analysis of Deleted ...https://shomir.net › pdf › publications › cscw2013_tweets_are_forevertice”, which includes a “user ID” and an “up-to-status ID”, will be sent to third party clients so they, in turn, can delete the location information of tweets from their ...
#
# Arts & Entertainment
# ----------------------------
# "Arts & Entertainment"near Lucas Valley-Marinwood, CAGregangelo's Velocity Arts & Entertainment 4.8  (56) Entertainment agency · San Francisco, CAOpen 24 hoursMuseum tours at artistic troupe's HQSan Jose City Arts & Culture   No reviews City government office · San Jose, CA
#
# College & University
# ----------------------------
# Institute For College & UniversityAssociation or organizationDirectionsAddress: 2040 Harrington Ave, Oakland, CA 94601Phone: (510) 533-6046
#
# Nightlife Spots
# ----------------------------
# "Nightlife Spots"near Lucas Valley-Marinwood, CAAndresen's Tavern 4.5  (68)  · $Cocktail bar · Petaluma, CAUnion Square 4.4  (26,565) Plaza · San Francisco, CAFamed hub for retail, dining & nightlifeMazzocco's Club 4.4  (44) Cocktail bar · Redwood City, CAMore places
#
# Great Outdoors
# ----------------------------
# The Great OutdoorsPG · 1988 ‧ Comedy/Adventure ‧ 1h 39mView all6.7/10 · IMDb
# 40% · Rotten Tomatoes
# 24% · Metacritic
# It's vacation time for outdoorsy Chicago man Chet Ripley (John Candy), along with his wife, Connie (Stephanie Faracy), and their two kids, Buck (Chris Young) and Ben (Ian Giatti). But a serene weekend of fishing at a Wisconsin lakeside cabin gets...Release date: June 17, 1988 (USA)Director: Howard DeutchScreenplay: John HughesBox office: 43.4 million USDBudget: 24 million USDCastJohn CandyChet RipleyDan AykroydRoman CraigStephanie FaracyConnie RipleyAnnette BeningKate CraigLucy DeakinsCammieChris YoungBuckPeople also search forSummer Rental1985Uncle Buck1989National Lampoon's Vacation1983National Lampoon's European Vacation1985National Lampoon's Christmas Vacation1989Career Opportunities1991
#
# Professional & Other Places
# ----------------------------
# THE BEST Lake, San Francisco Professional & Other Places ... - Lyfthttps://www.lyft.com › rider › city-guides › top-professional-and-other-pla...Discover the hottest professional & other places people ACTUALLY go to in Lake , San Francisco - Kittredge School, California Dental. Most popular destinations ...
#
# Shops & Services
# ----------------------------
# Shops & Services - The Shops at Kenilworthhttps://www.theshopsatkenilworth.com › shops-servicesShops & Services. Find that special gift. Pamper yourself with a massage. Try on the latest styles. With loads to discover and lots of free parking, The Shops at ...
#
# Travel & Transport
# ----------------------------
# Travel & Transport Inc - Company Profile and News - Bloomberg ...https://www.bloomberg.com › profile › companyTravel & Transport, Inc. provides travel services. The Company offers corporate travel solutions, vacation planning, and loyalty programs. Travel & Transport serves customers throughout the United States.
#
# Shop & Service
# ----------------------------
# The Tune Up Shop & Service Center 4.6  (18)
# Smog inspection station in Lodi, CaliforniaDirectionsWebsiteAddress: 1 W Lodi Ave, Lodi, CA 95240Hours: Closed ⋅ Opens 8:30AM ThuPhone: (209) 334-2654
#
# I regretted the minute I pressed share
# ----------------------------
# [PDF] I regretted the minute I pressed share - CUPS - Carnegie Mellon ...https://cups.cs.cmu.edu › soups › proceedings › a10_WangJul 22, 2011 · “I regretted the minute I pressed share”: A Qualitative Study of Regrets on Facebook. Yang Wang wang@cs.cmu.edu. Saranga Komanduri.
#
#
# Alves and Ferreira - 2011 - ReConMUC adaptable consistency requirements for e.pdf
#
#
# Alves and Ferreira - 2013 - Radiator context propagation based on delayed agg.pdf
#
#
# Ammari and Schoenebeck - 2016 - “Thanks for your interest in our Facebook group, b.pdf
#
# Thanks for your interest in our Facebook group, but it's only for dads:
# ----------------------------
# “Thanks for your interest in our Facebook group, but ... - Academia.eduhttps://www.academia.edu › “Thanks for your interest in our Facebook group, but it's only for dads:” Social Roles of Stay-at-Home Dads Tawfiq Ammari, Sarita Schoenebeck School of ...
#
# masculine things
# ----------------------------
# What are traditionally masculine things that you do and enjoy? - Reddithttps://www.reddit.com › MensLib › comments › what_are_traditionally_m...What are traditionally masculine things that you do and enjoy? 223 comments. share. save hide report. 88% Upvoted. This thread is archived. New comments ...
#
# homemade baby food
# ----------------------------
# 21 Homemade Baby Food Recipes - Healthlinehttps://www.healthline.com › health › childrens-health › homemade-baby-f...Why make homemade baby food? You don't have to be a master in the kitchen to make your own baby food. While convenient, commercial baby foods may lose ...
# Solid foods · Allergens and FYIs · 4–6 months · 7–9 months
#
# the part one is assigned to play
# ----------------------------
# Role Transitions: Explorations and Explanationshttps://books.google.com › books... noted that behavior often is determined less by characteristics of the person than by the part one is assigned to play. Thus, the dramaturgic metaphor (Sarbin,  ...
#
# location in the social system,
# ----------------------------
# Social Structure | Encyclopedia.comhttps://www.encyclopedia.com › sociology-general-terms-and-concepts › s...In terms of their structural location in the social system, which is centered on the means of production, men in society are divided by Marx into two strata, ...
#
# brute force
# ----------------------------
# People also askWhat is the meaning of brute force?Is brute force illegal?How does brute force work?How fast is a brute force attack?
#
# socialize with other stay-athome parents.
# ----------------------------
# Showing results for "socialize with other stay-at home parents."Search instead for "socialize with other stay-athome parents."
#
# better fit
# ----------------------------
# Better Fit - Urban Dictionaryhttps://www.urbandictionary.com › defineWe're phoning to let you know that you were not the successful candidate for the job. We found someone who was a "better fit" for the position.
#
# personal and flexible
# ----------------------------
# Professional, personal and flexible - Review of Tupiza Tours, Tupiza ...https://www.tripadvisor.com › ... › Tupiza - Things to Do › Tupiza ToursRating  5.0     · Review by a Tripadvisor userTupiza Tours: Professional, personal and flexible - See 860 traveler reviews, 721 candid photos, and great deals for Tupiza, Bolivia, at Tripadvisor.
#
# gender display
# ----------------------------
# Gender displayView allIn the book gender advertising by Erving Goffman it states: "If gender is defined as the culturally established correlates of sex (whether in consequence of biology or learning) then gender display refers to conventionalized portrayals of those correlates." Gender displays can otherwise be defined as rituals of gender ...
# Gender advertisement - Wikipedia
# Wikipedia › wiki › Gender_advertisement
#
# site of self-worth.
# ----------------------------
# Economic crises and emotional fallout: Work, home and men's ...https://www.researchgate.net › publication › 248601997_Economic_crises...... class families in Sydney after the financial crisis found that the crisis enabled men to invest less in their work and more in the home as a "site of self-worth.
#
# creative outlet
# ----------------------------
# Why Everyone Needs a Creative Outlet | A Healthier Michiganhttps://www.ahealthiermichigan.org › MindJan 15, 2019 · A break from anxiety and stress: A creative outlet can help fill a void in your life as well as distract you from stressful things like work. You're ...
#
# not only does he do the cooking—he built the kitchen!
# ----------------------------
# “Thanks for your interest in our Facebook group, but it's only for dads ...https://www.academia.edu › In one example, a father emphasized, “not only does he do the cooking—he built the kitchen!” Moisio et al. [51] argue that productive consumption through DIY ...
#
# set of expected
# ----------------------------
# Quiz 4 Flashcards | Quizlethttps://quizlet.com › quiz-4-flash-cardsA ______ is a set of expected behaviors for a particular position. 1. Maintenance role 2. Task role 3. Norm 4. Role 5. Competency. Role.
#
# significant role change the integrity of the self is jeopardized to some degree.
# ----------------------------
# Becoming an Ex: The Process of Role Exithttps://books.google.com › books(II4–15) As Blau (1973) points out, with each significant role change the integrity of the self is jeopardized to some degree. When the individual enters new roles ...
#
# variegated repertoire of ties
# ----------------------------
# [PDF] SIGCHI Conference Paper Format - Sarita Schoenebeck - University ...https://yardi.people.si.umich.edu › Schoenebeck_StayAtHomeFathers16one with a “variegated repertoire of ties” that provide a diverse set of roles within each dimension of their network. People can “shop for” help from different parts ...
#
# shop for
# ----------------------------
# Shop | Definition of Shop by Merriam-Websterhttps://www.merriam-webster.com › dictionary › shopBritannica English: Translation of shop for Arabic Speakers. Britannica.com: Encyclopedia article about shop. Comments on shop. What made you want to look ...
#
# normative standards
# ----------------------------
# When Do Normative Standards Matter Most? Understanding the ...https://www.tandfonline.com › doi › absThis study used norm strength to explore variation in normative standards at 52 locations in 13 U.S. national parks. The analysis measured and supported five ...
#
# need[ed] adult time
# ----------------------------
# Showing results for "needed] adult time"Search instead for "need[ed] adult time"
#
# quite often give me more scrutiny at the park.
# ----------------------------
# [PDF] SIGCHI Conference Paper Format - Sarita Schoenebeck - University ...https://yardi.people.si.umich.edu › Schoenebeck_StayAtHomeFathers16mothers “quite often give me more scrutiny at the park.” SAHD15 reported that “at least offline, not overtly. I have occasionally gotten looks [from SAHMs] if I take [ ...
#
# at least offline, not overtly. I have occasionally gotten looks [from SAHMs] if I take [my child] up to the park or something in the middle of the day.
# ----------------------------
# â•œThanks for your interest in our Facebook group, but it&aposhttps://dl.acm.org › doi › pdfjudgment in their offline environments. This research ... of place when taking his child to the park because all of the other caretakers in the ... SAHD15 reported that “at least offline, not overtly. I have occasionally gotten looks [from SAHMs] if I take [my child] up to the park or something in the middle of the day.” SAHD18 also ...
#
# early on, my audience was mostly women and mostly moms. And so they were pretty positive online.
# ----------------------------
# â•œThanks for your interest in our Facebook group, but it&aposhttps://dl.acm.org › doi › pdfother caretakers in the park are either stay-at-home moms. (SAHMs) or female ... mainly in that they do not “socialize with other stay-at- ... “early on, my audience was mostly women and mostly moms. And so they were pretty positive online.”.
#
# Twitter party
# ----------------------------
# Twitter partyView allA Twitter party is a live social media networking event where participants meet to talk about a certain theme or topic. Just like conventional parties, a Twitter party has a host, or a group of hosts. Those who join the party have to use a specific hashtag on their tweets.
# 6 Tips to Joining & Enjoying a Twitter Party | Brand24 Blog
# Brand24 › blog › 6-tips-to-joining-and-enjoying-a-twitter-party
#
# five-year or six-year hole in her career.
# ----------------------------
# [PDF] SIGCHI Conference Paper Format - Sarita Schoenebeck - University ...https://yardi.people.si.umich.edu › Schoenebeck_StayAtHomeFathers16have a “five-year or six-year hole in her career.” SAHD4 echoed this reasoning. He stayed home while his partner held a regular job because as a clinical social  ...
#
# not [a] provider, [was] not Christian.
# ----------------------------
# “Thanks for your interest in our Facebook group, but it's only for dads ...https://www.academia.edu › ... to a blog post intimating that any father who was “not [a] provider, [was] not Christian.” In his own blog post, he SAHDs used Pinterest to generate traffic to their ...
#
#
# Ammari et al. - 2017 - The Crafting of DIY Fatherhood.pdf
#
#
# Andalibi et al. - 2017 - Sensitive Self-disclosures, Responses, and Social .pdf
#
#
# Andrews et al. - 2016 - Keeping Up with the Tweet-dashians The Impact of .pdf
#
#
# André et al. - 2012 - Who gives a tweet evaluating microblog content va.pdf
#
#
# Arazy et al. - 2017 - On the How and Why of Emergent Role Behaviors .pdf
#
#
# Arif et al. - 2016 - How Information Snowballs Exploring the Role of E.pdf
#
#
# Arif et al. - 2017 - A Closer Look at the Self-Correcting Crowd Examin.pdf
#
#
# Bales et al. - 2011 - CoupleVIBE mobile implicit communication to impro.pdf
#
#
# Bateman et al. - 2013 - Social navigation for loosely-coupled information .pdf
#
#
# Bica et al. - 2017 - Visual Representations of Disaster.pdf
#
#
# Bin Morshed et al. - 2017 - When the Internet Goes Down in Bangladesh.pdf
#
#
# Borge et al. - 2012 - Patterns of team processes and breakdowns in infor.pdf
#
#
# Bowser et al. - 2017 - Accounting for Privacy in Citizen Science Ethical.pdf
#
#
# Brady et al. - 2013 - Investigating the appropriateness of social networ.pdf
#
#
# Brubaker and Hayes - 2011 - SELECT  FROM USER infrastructure and socio-techn.pdf
#
#
# Burke and Develin - 2016 - Once More with Feeling Supportive Responses to So.pdf
#
#
# Burke et al. - 2010 - Social use of computer-mediated communication by a.pdf
#
#
# Bødker et al. - 2016 - 'A Farmer, a Place and at least 20 Members' The D.pdf
#
#
# Chancellor et al. - 2016 - #thyghgapp Instagram Content Moderation and Lexic.pdf
#
#
# Chancellor et al. - 2016 - Quantifying and Predicting Mental Illness Severity.pdf
#
#
# Chen and Abouzied - 2016 - One LED is Enough Catalyzing Face-to-face Interac.pdf
#
#
# Cheng et al. - 2017 - Anyone Can Become a Troll Causes of Trolling Beha.pdf
#
#
# Chi et al. - 2011 - Smarter social collaboration at IBM research.pdf
#
#
# Choi and Tausczik - 2017 - Characteristics of Collaboration in the Emerging P.pdf
#
#
# Choi et al. - 2013 - Mining social relationship types in an organizatio.pdf
#
#
# Collier and Bear - 2012 - Conflict, criticism, or confidence an empirical e.pdf
#
#
# Dabbish et al. - 2012 - Social coding in GitHub transparency and collabor.pdf
#
#
# Dailey and Starbird - 2017 - Social Media Seamsters Stitching Platforms & Audi.pdf
#
#
# De Choudhury and Counts - 2013 - Understanding affect in the workplace via social m.pdf
#
#
# De Choudhury et al. - 2012 - Unfolding the event landscape on twitter classifi.pdf
#
#
# De Choudhury et al. - 2013 - Major life changes and behavioral markers in socia.pdf
#
#
# De Choudhury et al. - 2016 - Characterizing Dietary Choices, Nutrition, and Lan.pdf
#
#
# De Choudhury et al. - 2017 - Computational Approaches Toward Integrating Quanti.pdf
#
#
# De Choudhury et al. - 2017 - Gender and Cross-Cultural Differences in Social Me.pdf
#
#
# Dearman et al. - 2008 - An examination of daily information needs and shar.pdf
#
#
# DeVito et al. - 2017 - Platforms, People, and Perception Using Affordanc.pdf
#
#
# Dey et al. - 2017 - The Art and Science of Persuasion Not All Crowdfu.pdf
#
#
# Diakopoulos and Naaman - 2011 - Towards quality discourse in online news comments.pdf
#
#
# Dimond et al. - 2013 - Hollaback! the role of storytelling online in a so.pdf
#
#
# Dong et al. - 2016 - Embracing Cultural Diversity Online Social Ties i.pdf
#
#
# Dye et al. - 2016 - Early Adopters of the Internet and Social Media in.pdf
#
#
# Fiesler et al. - 2016 - Reality and Perception of Copyright Terms of Servi.pdf
#
#
# Fiesler et al. - 2017 - What (or Who) Is Public Privacy Settings and Soci.pdf
#
#
# Finn and Oreglia - 2016 - A Fundamentally Confused Document Situation Repor.pdf
#
#
# Foth et al. - 2011 - Urban informatics.pdf
#
#
# Gao et al. - 2013 - Closure vs. structural holes how social network i.pdf
#
#
# Georgiou et al. - 2017 - Extracting Topics with Focused Communities for Soc.pdf
#
#
# Gilbert - 2012 - Predicting tie strength in a new medium.pdf
#
#
# Gray et al. - 2013 - Who wants to know question-asking and answering p.pdf
#
#
# Grinberg et al. - 2017 - Understanding Feedback Expectations on Facebook.pdf
#
#
# Halpern et al. - 2013 - Designing collaboration comparing cases exploring.pdf
#
#
# Haraty et al. - 2017 - Online Customization Sharing Ecosystems Component.pdf
#
#
# Hardy and Lindtner - 2017 - Constructing a Desiring User Discourse, Rurality,.pdf
#
#
# Harmon et al. - 2017 - Supporting Everyday Philanthropy Care Work In Sit.pdf
#
#
# Harry et al. - 2012 - Setting the stage for interaction a tablet applic.pdf
#
#
# Hemphill et al. - 2013 - What's congress doing on twitter.pdf
#
#
# Hong et al. - 2012 - Designing a social network to support the independ.pdf
#
#
# Huang et al. - 2017 - Human Library Understanding Experience Sharing fo.pdf
#
#
# Isaacs et al. - 2012 - Integrating local and remote worlds through channe.pdf
#
#
# Israni et al. - 2017 - Snitches, Trolls, and Social Norms Unpacking Perc.pdf
#
#
# Jeon et al. - 2016 - First-Generation Students and College The Role of.pdf
#
#
# Johri - 2011 - Look ma, no email! blogs and IRC as primary and pr.pdf
#
#
# Jones and Altadonna - 2012 - We don't need no stinkin' badges examining the so.pdf
#
#
# Joseph et al. - 2017 - Girls Rule, Boys Drool Extracting Semantic and Af.pdf
#
#
# Karnik et al. - 2013 - Uses & gratifications of a facebook media sharing .pdf
#
#
# Kaziunas et al. - 2017 - Caring through Data Attending to the Social and E.pdf
#
#
# Keegan et al. - 2012 - Do editors or articles drive collaboration multil.pdf
#
#
# Keegan et al. - 2016 - Analyzing Organizational Routines in Online Knowle.pdf
#
#
# Kelly et al. - 2017 - Demanding by Design Supporting Effortful Communic.pdf
#
#
# Kim and Monroy-Hernandez - 2016 - Storia Summarizing Social Media Content based on .pdf
#
#
# Kim et al. - 2013 - Sensr evaluating a flexible framework for authori.pdf
#
#
# Kim et al. - 2017 - Mosaic Designing Online Creative Communities for .pdf
#
#
# Kivran-Swaine and Naaman - 2011 - Network properties and social sharing of emotions .pdf
#
#
# Kokkalis et al. - 2017 - Founder Center Enabling Access to Collective Soci.pdf
#
#
# Krafft et al. - 2017 - Bots as Virtual Confederates Design and Ethics.pdf
#
#
# Kriplean et al. - 2012 - Supporting reflective public thought with consider.pdf
#
#
# Kukka et al. - 2017 - Immersive Street-level Social Media in the 3D Virt.pdf
#
#
# Kulshrestha et al. - 2017 - Quantifying Search Bias Investigating Sources of .pdf
#
#
# Lampe et al. - 2013 - Users and nonusers interactions between levels of.pdf
#
#
# Laumer et al. - 2017 - The Challenge of Enterprise Social Networking (Non.pdf
#
#
# Lazar et al. - 2017 - Going Gray, Failure to Hire, and the Ick Factor A.pdf
#
#
# Leavitt and Robinson - 2017 - The Role of Information Visibility in Network Gate.pdf
#
#
# Leavitt et al. - 2016 - Uses of Multiple Characters in Online Games and Th.pdf
#
#
# Liao and Shi - 2013 - She gets a sports car from our donation rumor tra.pdf
#
#
# Liebman and Gergle - 2016 - It's (Not) Simply a Matter of Time The Relationsh.pdf
#
#
# Lin and Farnham - 2013 - Opportunities via extended networks for teens' inf.pdf
#
#
# Lindtner et al. - 2012 - Cultural appropriation information technologies a.pdf
#
#
# Litt and Hargittai - 2016 - “Just Cast the Net, and Hopefully the Right Fish S.pdf
#
#
# Liu and Jansen - 2013 - Factors influencing the response rate in social qu.pdf
#
#
# Liu et al. - 2011 - Improving communication and social support for car.pdf
#
#
# Liu et al. - 2017 - Assessing Behavior Stage Progression From Social M.pdf
#
#
# López and Butler - 2013 - Consequences of content diversity for online publi.pdf
#
#
# Ma et al. - 2017 - What Happens in Happn The Warranting Powers of Lo.pdf
#
#
# Magee et al. - 2017 - Four Factors that Regulate Teen Technology Use in .pdf
#
#
# Maity et al. - 2016 - #Bieber + #Blast = #BieberBlast Early Prediction .pdf
#
#
# Mark et al. - 2012 - Blogs as a collective war diary.pdf
#
#
# Marlow et al. - 2013 - Impression formation in online peer production ac.pdf
#
#
# Maruyama et al. - 2017 - Social Watching a Civic Broadcast Understanding t.pdf
#
#
# Mashhadi et al. - 2013 - Putting ubiquitous crowd-sourcing into context.pdf
#
#
# Mason and Clauset - 2013 - Friends FTW! friendship and competition in halo r.pdf
#
#
# Massimi et al. - 2012 - Finding a new normal the role of technology in li.pdf
#
#
# Matias et al. - 2017 - FollowBias Supporting Behavior Change toward Gend.pdf
#
#
# Mendel and Toch - 2017 - Susceptibility to Social Influence of Privacy Beha.pdf
#
#
# Menking et al. - 2017 - Who Wants to Read This A Method for Measuring Top.pdf
#
#
# Mentis et al. - 2012 - Taking as an act of sharing.pdf
#
#
# Merritt et al. - 2017 - Kurator Using The Crowd to Help Families With Per.pdf
#
#
# Mitra et al. - 2017 - A Parsimonious Language Model of Social Media Cred.pdf
#
# Perfect). Table 6(b) displays the corresponding credit matrix. Level-1 Weight0.5 Accuracy: Here a partial credit of 0.5 was rewarded if the classiﬁer prediction was incorrect by one level. The credit matrix corresponds to the one shown in Table 6(b), but 0.25 replaced with 0.5. Level-2 Weight0.25,0.5 Accuracy: This is our most lenient classiﬁer which rewarded a partial credit of 0.5 for misclassiﬁcation by one level and a partial credit of 0.25 for mis-classiﬁcations by two levels (Table 6(c)). We compared the performance of our language classiﬁer against two baseline classiﬁers: 1) Random-Guess baseline and 2) Random-Weighted-Guess baseline. In the random guess classiﬁer, every credibility class had an equal probability of being selected. Hence the classiﬁer randomly guessed and predicted any of the four possible credibility categories. On the other hand, the predictions of random-weighted guess classiﬁer were based on the proportion of instances that belonged to each credibility class in our dataset. We opted for the random guess baseline classiﬁers over a choose-most-frequent-class baseline so as to illustrate a sensible baseline performance for each credibility category. We performed McNemar's test of signiﬁcance to compare the accuracy of our language classiﬁer with that of the baseline. McNemar's test, which assessed whether the proportion of correct and incorrect classiﬁcations in the two systems are signiﬁcantly different, indicated that even with the most conservative approach employing an unweighted credit matrix, our language classiﬁer accuracy was signiﬁcantly higher compared to both the baseline classiﬁers (p < 10−16). Table 5 shows the precision, recall and F1 measures for each credibility class under different accuracy measurement schemes as well as the overall accuracy under each scheme. DISCUSSION According to our ﬁndings, the top predictive linguistic features associated with higher perceived credibility mostly comprise linguistic measures. The only control variable in the top 100 predictors of high credibility scores was average retweet length (β = 0.25), while average reply length (β = 0.18) fell within the top 200 positive predictors. Similarly, top predictive features of lower perceived credibility scores were phrases from our language categories. Number of retweets (β = – 0.27) was the only control in the topmost 50 predictors of low perceived credibility scores. This indicates that while higher number of retweets were correlated with lower credibility scores, retweets and replies with longer message lengths were associated with higher credibility scores. An explanation of this could be that longer message length of retweets and replies denote more information and greater reasoning, leading to higher perceived credibility. On the other hand, higher number of retweets (marker of lower perceived credibility score) might represent an attempt to elicit collective reasoning or ascertain situational awareness during times of crisis and uncertainty [61]. Session: Content QualityCSCW 2017, February 25–March 1, 2017, Portland, OR, USA134 Figure 1: The predictive power of the linguistic measures from the omnibus model. A measure's weight is proportional to the deviance of the corresponding linguistic category (Table 4 lists the deviance numbers). The color saturation corresponds to the difference in the absolute values of positive and negative β weights of the coefﬁcients belonging to the linguistic category. The color spans from red to green with a higher concentration of red denoting that the sum of negative βs is higher than the sum of positive βs, while the converse is true for higher concentration of green. The diagram also lists the top predictive phrases in each linguistic measure. Among non-lexicon based features, fraction of quotations in original tweets was negatively correlated with credibility (β = – 0.097). Indeed, a key pragmatic goal of messages with quoted content is to convey uncertainty and prove ...
# ----------------------------
# Showing results for "Perfect). Table 6(b) displays the corresponding credit matrix. Level-1 Weight 0.5 Accuracy: Here a partial credit of 0.5 was rewarded if the classiﬁer prediction was incorrect by one level. The credit matrix corresponds to the one shown in Table 6(b), but 0.25 replaced with 0.5. Level-2 Weight 0.25,0.5 Accuracy: This is our most lenient classiﬁer which rewarded a partial credit of 0.5 for misclassiﬁcation by one level and a partial credit of 0.25 for mis-classiﬁcations by two levels (Table 6(c)). We compared the performance of our language classiﬁer against two baseline classiﬁers: 1) Random-Guess baseline and 2) Random-Weighted-Guess baseline. In the random guess classiﬁer, every credibility class had an equal probability of being selected. Hence the classiﬁer randomly guessed and predicted any of the four possible credibility categories. On the other hand, the predictions of random-weighted guess classiﬁer were based on the proportion of instances that belonged to each credibility class in our dataset. We opted for the random guess baseline classiﬁers over a choose-most-frequent-class baseline so as to illustrate a sensible baseline performance for each credibility category. We performed McNemar's test of signiﬁcance to compare the accuracy of our language classiﬁer with that of the baseline. McNemar's test, which assessed whether the proportion of correct and incorrect classiﬁcations in the two systems are signiﬁcantly different, indicated that even with the most conservative approach employing an unweighted credit matrix, our language classiﬁer accuracy was signiﬁcantly higher compared to both the baseline classiﬁers (p < 10−16). Table 5 shows the precision, recall and F1 measures for each credibility class under different accuracy measurement schemes as well as the overall accuracy under each scheme. DISCUSSION According to our ﬁndings, the top predictive linguistic features associated with higher perceived credibility mostly comprise linguistic measures. The only control variable in the top 100 predictors of high credibility scores was average retweet length (β = 0.25), while average reply length (β = 0.18) fell within the top 200 positive predictors. Similarly, top predictive features of lower perceived credibility scores were phrases from our language categories. Number of retweets (β = – 0.27) was the only control in the topmost 50 predictors of low perceived credibility scores. This indicates that while higher number of retweets were correlated with lower credibility scores, retweets and replies with longer message lengths were associated with higher credibility scores. An explanation of this could be that longer message length of retweets and replies denote more information and greater reasoning, leading to higher perceived credibility. On the other hand, higher number of retweets (marker of lower perceived credibility score) might represent an attempt to elicit collective reasoning or ascertain situational awareness during times of crisis and uncertainty [61]. Session: Content QualityCSCW 2017, February 25–March 1, 2017, Portland, OR, USA134 Figure 1: The predictive power of the linguistic measures from the omnibus model. A measure's weight is proportional to the deviance of the corresponding linguistic category (Table 4 lists the deviance numbers). The color saturation corresponds to the difference in the absolute values of positive and negative β weights of the coefﬁcients belonging to the linguistic category. The color spans from red to green with a higher concentration of red denoting that the sum of negative βs is higher than the sum of positive βs, while the converse is true for higher concentration of green. The diagram also lists the top predictive phrases in each linguistic measure. Among non-lexicon based features, fraction of quotations in original tweets was negatively correlated with credibility (β = – 0.097). Indeed, a key pragmatic goal of messages with quoted content is to conve ...
#
#
# Monroy-Hernández et al. - 2013 - The new war correspondents the rise of civic medi.pdf
#
#
# Morgan et al. - 2013 - Is news sharing on Twitter ideologically biased.pdf
#
#
# Morris - 2013 - Collaborative search revisited.pdf
#
#
# Morris et al. - 2012 - Tweeting is believing understanding microblog cre.pdf
#
#
# Mullarkey - 2012 - Socially immature organizations a typology of soc.pdf
#
#
# Munson et al. - 2011 - Thanks and tweets comparing two public displays.pdf
#
#
# Murphy-Hill and Murphy - 2011 - Peer interaction effectively, yet infrequently, en.pdf
#
#
# Naaman et al. - 2010 - Is it really about me message content in social a.pdf
#
#
# Nagpal et al. - 2012 - Friends, romans, countrymen lend me your URLs. us.pdf
#
#
# Nakikj and Mamykina - 2017 - A Park or A Highway Overcoming Tensions in Design.pdf
#
#
# Neustaedter and Golbeck - 2013 - Exploring pet video chat the remote awareness and.pdf
#
#
# Nichols and Kang - 2012 - Asking questions of targeted strangers on social n.pdf
#
#
# Nichols et al. - 2013 - Analyzing the quality of information solicited fro.pdf
#
#
# O'Kane et al. - 2013 - Non-static nature of patient consent shifting pri.pdf
#
#
# O'Leary et al. - 2017 - Design Opportunities for Mental Health Peer Suppor.pdf
#
#
# Olteanu et al. - 2017 - Distilling the Outcomes of Personal Experiences A.pdf
#
#
# Pace et al. - 2013 - From organizational to community creativity parag.pdf
#
#
# Page et al. - 2013 - What a tangled web we weave lying backfires in lo.pdf
#
#
# Pan and Thomas - 2012 - Hot or not a qualitative study on ecological impa.pdf
#
#
# Pan et al. - 2013 - To answer or not what non-qa social activities ca.pdf
#
#
# Panovich et al. - 2012 - Tie strength in question & answer on social networ.pdf
#
#
# Paredes et al. - 2017 - Inquire Large-scale Early Insight Discovery for Q.pdf
#
#
# Park et al. - 2016 - Persistent Sharing of Fitness App Status on Twitte.pdf
#
#
# Pater and Mynatt - 2017 - Defining Digital Self-Harm.pdf
#
#
# Pater et al. - 2016 - “Hunger Hurts but Starving Works” Characterizing .pdf
#
#
# Pelleg et al. - 2016 - When the Crowd is Not Enough Improving User Exper.pdf
#
#
# Qu et al. - 2011 - Microblogging after a major disaster in China a c.pdf
#
#
# Quercia et al. - 2012 - The personality of popular facebook users.pdf
#
#
# Quercia et al. - 2012 - Tracking gross community happiness from tweets.pdf
#
#
# Reeves and Brown - 2016 - Embeddedness and sequentiality in social media.pdf
#
#
# Robson et al. - 2013 - Comparing the use of social networking and traditi.pdf
#
#
# Rost et al. - 2013 - Representation and communication challenges in in.pdf
#
#
# Rotman et al. - 2012 - Dynamic changes in motivation in collaborative cit.pdf
#
#
# Said et al. - 2013 - User-centric evaluation of a K-furthest neighbor c.pdf
#
#
# Samory et al. - 2017 - Quotes Reveal Community Structure and Interaction .pdf
#
#
# Sarcevic et al. - 2012 - Beacons of hope in decentralized coordination l.pdf
#
#
# Savage et al. - 2016 - Botivist Calling Volunteers to Action using Onlin.pdf
#
#
# Schoenebeck et al. - 2016 - Playful Backstalking and Serious Impression Manage.pdf
#
#
# Schroeter - 2012 - Engaging new digital locals with interactive urban.pdf
#
#
# Scissors et al. - 2016 - What's in a Like Attitudes and behaviors around r.pdf
#
#
# Semaan and Mark - 2011 - Creating a context of trust with ICTs restoring a.pdf
#
#
# Semaan and Mark - 2012 - 'facebooking' towards crisis recovery and beyond .pdf
#
#
# Semaan et al. - 2017 - Military Masculinity and the Travails of Transitio.pdf
#
#
# Sha et al. - 2013 - Trend makers and trend spotters in a mobile applic.pdf
#
#
# Shami et al. - 2011 - Browse and discover social file sharing in the en.pdf
#
#
# Shamma et al. - 2011 - Peaks and persistence modeling the shape of micro.pdf
#
#
# Shamma et al. - 2016 - Finding Weather Photos Community-Supervised Metho.pdf
#
#
# Sharma and Cosley - 2016 - Distinguishing between Personal Preferences and So.pdf
#
#
# Shklovski et al. - 2008 - Finding community through information and communic.pdf
#
#
# Singer et al. - 2013 - Mutual assessment in the social programmer ecosyst.pdf
#
#
# Singh et al. - 2017 - They basically like destroyed the school one day.pdf
#
#
# Sleeper et al. - 2013 - The post that wasn't exploring self-censorship on.pdf
#
#
# Smith et al. - 2013 - Finger on the pulse identifying deprivation using.pdf
#
#
# Starbird and Palen - 2012 - (How) will the revolution be retweeted informatio.pdf
# ---------------------------------------------------------------------------
# PSEOF                                     Traceback (most recent call last)
# <ipython-input-11-b5fbd8f65ae6> in <module>
#       6         print(filename)
#       7         print()
# ----> 8         check_quotes(find_quotes(convert_pdf_to_txt('./PDFs/' + filename)))
#       9         print()
#
# <ipython-input-3-4a6dc998d567> in convert_pdf_to_txt(pdf_filepath, password, max_pages, caching, page_num)
#       9         with TextConverter(rsrcmgr, return_string, codec=codec, laparams=laparams) as device:
#      10             interpreter = PDFPageInterpreter(rsrcmgr, device)
# ---> 11             for page in PDFPage.get_pages(open_file, page_num, maxpages=max_pages, password=password, caching=caching, check_extractable=True):
#      12                 interpreter.process_page(page)
#      13             paper_string = return_string.getvalue()
#
# ~\miniconda3\lib\site-packages\pdfminer\pdfpage.py in get_pages(cls, fp, pagenos, maxpages, password, caching, check_extractable)
#     125         parser = PDFParser(fp)
#     126         # Create a PDF document object that stores the document structure.
# --> 127         doc = PDFDocument(parser, password=password, caching=caching)
#     128         # Check if the document allows text extraction. If not, abort.
#     129         if check_extractable and not doc.is_extractable:
#
# ~\miniconda3\lib\site-packages\pdfminer\pdfdocument.py in __init__(self, parser, password, caching, fallback)
#     552             parser.fallback = True
#     553             xref = PDFXRefFallback()
# --> 554             xref.load(parser)
#     555             self.xrefs.append(xref)
#     556         for xref in self.xrefs:
#
# ~\miniconda3\lib\site-packages\pdfminer\pdfdocument.py in load(self, parser)
#     175             # expand ObjStm.
#     176             parser.seek(pos)
# --> 177             (_, obj) = parser.nextobject()
#     178             if isinstance(obj, PDFStream) \
#     179                     and obj.get('Type') is LITERAL_OBJSTM:
#
# ~\miniconda3\lib\site-packages\pdfminer\psparser.py in nextobject(self)
#     565         """
#     566         while not self.results:
# --> 567             (pos, token) = self.nexttoken()
#     568             if isinstance(token, (int, float, bool, str, bytes, PSLiteral)):
#     569                 # normal token
#
# ~\miniconda3\lib\site-packages\pdfminer\psparser.py in nexttoken(self)
#     491     def nexttoken(self):
#     492         while not self._tokens:
# --> 493             self.fillbuf()
#     494             self.charpos = self._parse1(self.buf, self.charpos)
#     495         token = self._tokens.pop(0)
#
# ~\miniconda3\lib\site-packages\pdfminer\psparser.py in fillbuf(self)
#     219         self.buf = self.fp.read(self.BUFSIZ)
#     220         if not self.buf:
# --> 221             raise PSEOF('Unexpected EOF')
#     222         self.charpos = 0
#     223         return
#
# PSEOF: Unexpected EOF

# %%
print(find_quotes(convert_pdf_to_txt('./Twitter_CSCW/' + '2531602.2531734.pdf')))
# Out:
# ['rich emotional, psychological and sociocultural phenomenon', 'people are more likely to swear in relaxed environments than in formal environments', 'you are so gay', 'Bill Clinton urges Illinois to approve gay marriage bill', 'the main purpose of cursing is to express emotions, especially anger and frustration.', 'And all I need is one fuckin sheet stamped! #rage', 'fucking love you.', 'Where da fuq is the sun at, this weather is so #depressing', 'My life fell apart a long ass time ago.. So everythings normal i guess.', 'Soo pissed off', "People laugh when I say I work at McDonald's. And I say, bitch at least I have a job! At least I don't bother my parents asking them for $$$", 'Across the ocean, across the sea starting to hate the fucking distance between Justin Bieber and me.', '@user you little whore TAKE ME WITH YOU', 'Dear Marilyn Manson, I fucking love you and your music. The end.', 'profane al. comments are more popular or more widely read than nonprofane comments', 'who says curse words to whom', '@Harry Styles follow me babe<3', "@NiallOfﬁcial I can't sleep :(", '@taylorswift13 slut', '@Harry Styles slut drop on my follow button :))))))))']

# %%
check_quotes(find_quotes(convert_pdf_to_txt('./Twitter_CSCW/' + '2531602.2531734.pdf')))

# %%
def check_twitter(original):
    text = original
    text = urllib.parse.quote(text)
    url = 'https://twitter.com/search?q={}&src=recent_search_click'.format(text)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    file = open('test.html', 'w', encoding='utf-8')
    file.write(str(soup))
    file.close()
    for g in soup.find_all(class_='css-1dbjc4n r-my5ep6 r-qklmqi r-1adg3ll'):
        print(g.text)
#         here = (original in g.text and "did not match any documents" not in g.text)
#         if here:
#            s = original + "\n" + "----------------------------" + "\n" + g.text
#             return(s)
    return ''

# %%
check_twitter("fdafdsafdsa")
# Out:
# ''

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install TwitterSearch
# Out:
# Collecting TwitterSearch
#   Downloading TwitterSearch-1.0.2.tar.gz (20 kB)
# Requirement already satisfied: requests>=1.0.0 in c:\users\espen\miniconda3\lib\site-packages (from TwitterSearch) (2.22.0)
# Collecting requests-oauthlib>=0.3.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\espen\miniconda3\lib\site-packages (from requests>=1.0.0->TwitterSearch) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\espen\miniconda3\lib\site-packages (from requests>=1.0.0->TwitterSearch) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\espen\miniconda3\lib\site-packages (from requests>=1.0.0->TwitterSearch) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\espen\miniconda3\lib\site-packages (from requests>=1.0.0->TwitterSearch) (2.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Building wheels for collected packages: TwitterSearch
#   Building wheel for TwitterSearch (setup.py): started
#   Building wheel for TwitterSearch (setup.py): finished with status 'done'
#   Created wheel for TwitterSearch: filename=TwitterSearch-1.0.2-py3-none-any.whl size=18443 sha256=1373b002495fd997d0f2637132936c3a6c4185368022dca20f60e4a62f9b3ec0
#   Stored in directory: c:\users\espen\appdata\local\pip\cache\wheels\d5\74\5f\f344ffff31a93ee504581a51aad34120bf05bd749493365840
# Successfully built TwitterSearch
# Installing collected packages: oauthlib, requests-oauthlib, TwitterSearch
# Successfully installed TwitterSearch-1.0.2 oauthlib-3.1.0 requests-oauthlib-1.3.0
